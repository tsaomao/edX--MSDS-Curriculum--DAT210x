# %% [markdown]
# # DAT210x - Programming with Python for DS

# %% [markdown]
# ## Module3 - Lab5

# %% [markdown]
# This code is intentionally missing! Read the directions on the course lab page!

# %%
# Despite instructions, I am selectively copy/pasting code from Lab4
# instead of copying the notebook file
from pandas.tools.plotting import andrews_curves

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
# Pretty visuals
matplotlib.style.use('ggplot')
# if this line throws an error, use plt.style.use('ggplot') instead

# %%
df = pd.read_csv('./Datasets/wheat.data', index_col=0)

# %%
df = df.loc[:, ['compactness', 'length', 'width', 'asymmetry', 'groove', 'wheat_type']]

# %%
# Andrews Curves
plt.figure()
andrews_curves(df, 'wheat_type')
plt.show()
# Out:
# /Users/malcolmgin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: 'pandas.tools.plotting.andrews_curves' is deprecated, import 'pandas.plotting.andrews_curves' instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Reload dataset to get area and perimeter back
df = pd.read_csv('./Datasets/wheat.data', index_col=0)

# %%
# Redraw Andrews Curves
plt.figure()
andrews_curves(df, 'wheat_type')
plt.show()
# Out:
# /Users/malcolmgin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: 'pandas.tools.plotting.andrews_curves' is deprecated, import 'pandas.plotting.andrews_curves' instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
