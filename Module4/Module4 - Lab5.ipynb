# %% [markdown]
# # DAT210x - Programming with Python for DS

# %% [markdown]
# ## Module4- Lab5

# %%
# Magic command, works inside jupyter notebooks
# This includes an interactive control/renderer and does not require plt.show()
# %matplotlib notebook

# %%
import pandas as pd
import random

from scipy import misc
from mpl_toolkits.mplot3d import Axes3D
import matplotlib
import matplotlib.pyplot as plt

import math, random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import scipy.io

from mpl_toolkits.mplot3d import Axes3D

# %%
# Look pretty...

# matplotlib.style.use('ggplot')
plt.style.use('ggplot')

# %% [markdown]
# Create a regular Python list (not NDArray) and name it `samples`:

# %%
samples = []
colors = []

# %% [markdown]
# Code up a for-loop that iterates over the images in the `Datasets/ALOI/32/` folder. Look in the folder first, so you know how the files are organized, and what file number they start from and end at.
#
# Load each `.png` file individually in your for-loop using the instructions provided in the Feature Representation reading. Once loaded, flatten the image into a single-dimensional NDArray and append it to your `samples` list.
#
# **Optional**: You can resample the image down by a factor of two if you have a slower computer. You can also scale the image from `0-255` to `0.0-1.0` if you'd like--doing so shouldn't have any effect on the algorithm's results.

# %%
# Uses the Image module (PIL)
from scipy import misc
import os

pathstr = '/Users/malcolmgin/Dropbox/MSDS/DAT210x-working/edX--MSDS-Curriculum--DAT210x/Module4/Datasets/ALOI/32'
directory = os.fsencode(pathstr)

for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if filename.endswith(".png"): 
        # Load the image up
        img = misc.imread(pathstr + '/' + filename)
        samples.append(img.flatten().reshape(27648, 1)[:, 0])
        colors.append('b')
        continue

# %% [markdown]
# Convert `samples` to a DataFrame named `df`:

# %%
df = pd.DataFrame(samples)

# %% [markdown]
# Import any necessary libraries to perform Isomap here, reduce `df` down to three components and using `K=6` for your neighborhood size:

# %%
from sklearn import manifold
iso = manifold.Isomap(n_neighbors=6, n_components=3)
T = iso.fit_transform(df)

# %% [markdown]
# Create a 2D Scatter plot to graph your manifold. You can use either `'o'` or `'.'` as your marker. Graph the first two isomap components:

# %%
num_images, num_pixels = df.shape
num_pixels = int(math.sqrt(num_pixels))

fig = plt.figure()
    
ax = fig.add_subplot(111)
ax.set_title('First Two')
ax.set_xlabel('x')
ax.set_ylabel('y')
    
x_size = (max(T[:,0]) - min(T[:,0])) * 0.08
y_size = (max(T[:,1]) - min(T[:,1])) * 0.08
    
ax.scatter(T[:,0],T[:,1], marker='o',alpha=1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Chart a 3D Scatter plot to graph your manifold. You can use either `'o'` or `'.'` as your marker:

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

matplotlib.style.use('ggplot')

fig = plt.figure(figsize=(8, 5))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(T[:, 0], T[:, 1], T[:, 2], c = 'red', marker='o')

ax.set_title('Isomap 3D plot')
ax.set_xlabel('T2:0')
ax.set_ylabel('T2:1')
ax.set_zlabel('T2:2')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# Answer the first two lab questions!

# %% [markdown]
# Create another for loop. This time it should iterate over all the images in the `Datasets/ALOI/32_i` directory. Just like last time, load up each image, process them the way you did previously, and append them into your existing `samples` list:

# %%
# Uses the Image module (PIL)
from scipy import misc
import os

pathstr = '/Users/malcolmgin/Dropbox/MSDS/DAT210x-working/edX--MSDS-Curriculum--DAT210x/Module4/Datasets/ALOI/32i'
directory = os.fsencode(pathstr)

for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if filename.endswith(".png"): 
        # Load the image up
        img = misc.imread(pathstr + '/' + filename)
        samples.append(img.flatten().reshape(27648, 1)[:, 0])
        colors.append('r')
        continue

# %% [markdown]
# Convert `samples` to a DataFrame named `df`:

# %%
df = pd.DataFrame(samples)

# %% [markdown]
# Import any necessary libraries to perform Isomap here, reduce `df` down to three components and using `K=6` for your neighborhood size:

# %%
from sklearn import manifold
iso = manifold.Isomap(n_neighbors=6, n_components=3)
Ti = iso.fit_transform(df)

# %% [markdown]
# Create a 2D Scatter plot to graph your manifold. You can use either `'o'` or `'.'` as your marker. Graph the first two isomap components:

# %%
num_images, num_pixels = df.shape
num_pixels = int(math.sqrt(num_pixels))

fig = plt.figure()
    
ax = fig.add_subplot(111)
ax.set_title('First Two with i directory')
ax.set_xlabel('x')
ax.set_ylabel('y')
    
x_size = (max(Ti[:,0]) - min(Ti[:,0])) * 0.08
y_size = (max(Ti[:,1]) - min(Ti[:,1])) * 0.08
    
ax.scatter(Ti[:,0],Ti[:,1], marker='o', color=colors, alpha=1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Chart a 3D Scatter plot to graph your manifold. You can use either `'o'` or `'.'` as your marker:

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

matplotlib.style.use('ggplot')

fig = plt.figure(figsize=(8, 5))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(Ti[:, 0], Ti[:, 1], Ti[:, 2], c = colors, marker='o')

ax.set_title('Isomap 3D plot with i images')
ax.set_xlabel('T2:0')
ax.set_ylabel('T2:1')
ax.set_zlabel('T2:2')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
